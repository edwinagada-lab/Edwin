# %%
#6-3-23
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\USER\all_recs.xlsx")
df
# Out:
# C:\Users\USER\miniconda3\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                      Date                    Location  \
# 0              31/12/2022  Iran (Islamic Republic of)
# 1              31/12/2022    United States of America
# 2              30/12/2022                      Poland
# 3              30/12/2022    United States of America
# 4              30/12/2022  Iran (Islamic Republic of)
# ...                   ...                         ...
# 4723  2016-08-01 00:00:00                     Nigeria
# 4724  2016-08-01 00:00:00                     Nigeria
# 4725  2016-08-01 00:00:00                    Pakistan
# 4726  2016-08-01 00:00:00                     Nigeria
# 4727  2016-08-01 00:00:00                       India
#
#                                                  Victim  \
# 0                            State-run Iranian Websites
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\USER

# %%
import pandas as pd
year_order=df["Date"].value_counts().index
location_order=df["Location"].value_counts().index
motive_order=df["Motive"].value_counts().index
industry_order=df["Industry"].value_counts().index

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
df = pd.read_excel(r"C:\Users\USER\all_recs.xlsx")
plt.figure(figsize=(20,20))
plt.title("Attack frequency per year")
sb.countplot(
    data=df,
    y="Date",
    color= sb.color_palette()[3]
)
plt.xticks(rotation=45);
plt.show()
# Out:
# C:\Users\USER\miniconda3\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
df = pd.read_excel(r"C:\Users\USER\all_recs.xlsx")
plt.figure(figsize=(20,20))
plt.title("Attack frequency per year")
sb.countplot(
    data=df,
    y="Location",
    color=sb.color_palette()[3]
)
plt.xticks(rotation=45);
plt.show()
# Out:
# C:\Users\USER\miniconda3\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
df = pd.read_excel(r"C:\Users\USER\all_recs.xlsx")
plt.figure(figsize=(20,20))
plt.title("Attack frequency per year")
sb.countplot(
    data=df,
    y="Motive",
    color=sb.color_palette()[3]
)
plt.xticks(rotation=45);
plt.show()
# Out:
# C:\Users\USER\miniconda3\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# C:\Users\USER\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 63427 (\uf7c3) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
df = pd.read_excel(r"C:\Users\USER\all_recs.xlsx")
plt.figure(figsize=(20,20))
plt.title("Attack frequency per year")
sb.countplot(
    data=df,
    y="Industry",
    color=sb.color_palette()[3]
)
plt.xticks(rotation=45);
plt.show()
# Out:
# C:\Users\USER\miniconda3\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
